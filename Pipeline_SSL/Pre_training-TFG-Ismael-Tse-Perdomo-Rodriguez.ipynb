# %% [markdown]
# ## Getting Started

# %%
# !pip install -U albumentations -q
# !pip install -q tqdm
# !pip install -q vit-pytorch
# !pip install -q einops
# !pip install -q batchgenerators
# !pip install -q timm
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 165.3/165.3 kB 4.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.9/14.9 MB 48.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.4/13.4 MB 82.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.5/313.5 kB 41.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.7/119.7 kB 3.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 5.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 54.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.7/61.7 kB 2.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.4/96.4 kB 4.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 12.0 MB/s eta 0:00:00

# %%
ls
# Out:
# drive/  sample_data/

# %% [markdown]
# ## Preprocesamiento de imagenes

# %%
# !pip install -q batchgenerators

# %%
import os
import shutil
import numpy as np
from batchgenerators.utilities.file_and_folder_operations import *
from skimage import io
import cv2
from google.colab.patches import cv2_imshow
import random

# %% [markdown]
# ### Directorio T10

# %%
train_x = subfiles('/content/drive/MyDrive/TFG/Parte2/target_data/train/x')
val_x = subfiles('/content/drive/MyDrive/TFG/Parte2/target_data/val/x')


num_files_to_copy = 10

files_to_copy_train = random.sample(train_x, num_files_to_copy)

for file_path in files_to_copy_train:
  file_name = os.path.basename(file_path)
  num = file_name.split('-')[1]
  shutil.copy(file_path, f'/content/drive/MyDrive/TFG/Parte2/Dataset_10/train/x/{file_name}')
  shutil.copy(f'/content/drive/MyDrive/TFG/Parte2/target_data/train/y/training_groundtruth-{num}', f'/content/drive/MyDrive/TFG/Parte2/Dataset_10/train/y/training_groundtruth-{num}')


num_files_to_copy_val = 20

files_to_copy_val = random.sample(val_x, num_files_to_copy_val)

for file_path in files_to_copy_val:
  file_name = os.path.basename(file_path)
  num = file_name.split('-')[1]
  shutil.copy(file_path, f'/content/drive/MyDrive/TFG/Parte2/Dataset_10/val/x/{file_name}')
  shutil.copy(f'/content/drive/MyDrive/TFG/Parte2/target_data/val/y/training_groundtruth-{num}', f'/content/drive/MyDrive/TFG/Parte2/Dataset_10/val/y/{num}')

# %% [markdown]
# ### Directorio T 50

# %%
train_x = subfiles('/content/drive/MyDrive/TFG/Parte2/target_data/train/x')
val_x = subfiles('/content/drive/MyDrive/TFG/Parte2/target_data/val/x')


num_files_to_copy = 50

files_to_copy_train = random.sample(train_x, num_files_to_copy)

for file_path in files_to_copy_train:
  file_name = os.path.basename(file_path)
  num = file_name.split('-')[1]
  shutil.copy(file_path, f'/content/drive/MyDrive/TFG/Parte2/Dataset_50/train/x/{file_name}')
  shutil.copy(f'/content/drive/MyDrive/TFG/Parte2/target_data/train/y/training_groundtruth-{num}', f'/content/drive/MyDrive/TFG/Parte2/Dataset_50/train/y/training_groundtruth-{num}')


num_files_to_copy_val = 20

files_to_copy_val = random.sample(val_x, num_files_to_copy_val)

for file_path in files_to_copy_val:
  file_name = os.path.basename(file_path)
  num = file_name.split('-')[1]
  shutil.copy(file_path, f'/content/drive/MyDrive/TFG/Parte2/Dataset_50/val/x/{file_name}')
  shutil.copy(f'/content/drive/MyDrive/TFG/Parte2/target_data/val/y/training_groundtruth-{num}', f'/content/drive/MyDrive/TFG/Parte2/Dataset_50/val/y/{num}')

# %% [markdown]
# ### Directorio T100

# %%
train_x = subfiles('/content/drive/MyDrive/TFG/Parte2/target_data/train/x')
val_x = subfiles('/content/drive/MyDrive/TFG/Parte2/target_data/val/x')


num_files_to_copy = 100

files_to_copy_train = random.sample(train_x, num_files_to_copy)

for file_path in files_to_copy_train:
  file_name = os.path.basename(file_path)
  num = file_name.split('-')[1]
  shutil.copy(file_path, f'/content/drive/MyDrive/TFG/Parte2/Dataset_100/train/x/{file_name}')
  shutil.copy(f'/content/drive/MyDrive/TFG/Parte2/target_data/train/y/training_groundtruth-{num}', f'/content/drive/MyDrive/TFG/Parte2/Dataset_100/train/y/training_groundtruth-{num}')


num_files_to_copy_val = 40

files_to_copy_val = random.sample(val_x, num_files_to_copy_val)

for file_path in files_to_copy_val:
  file_name = os.path.basename(file_path)
  num = file_name.split('-')[1]
  shutil.copy(file_path, f'/content/drive/MyDrive/TFG/Parte2/Dataset_100/val/x/{file_name}')
  shutil.copy(f'/content/drive/MyDrive/TFG/Parte2/target_data/val/y/training_groundtruth-{num}', f'/content/drive/MyDrive/TFG/Parte2/Dataset_100/val/y/{num}')

# %% [markdown]
# ### Pequeño directorio de prueba
# Contiene solo 500 imagenes

# %%
images = subfiles('/content/drive/MyDrive/TFG/Parte2/images')

num_files_to_copy = 500

files_to_copy = random.sample(images, num_files_to_copy)

for file_path in files_to_copy:
  file_name = os.path.basename(file_path)
  imagen = io.imread(file_path)
  nueva_imagen = cv2.resize(imagen, (1024, 512), interpolation = cv2.INTER_NEAREST)
  io.imsave(f'/content/drive/MyDrive/TFG/Parte2/little_images/{file_name}', nueva_imagen, check_contrast=False)

# %% [markdown]
# Cambiar el nombre a los archivos

# %%
images = subfiles('/content/drive/MyDrive/TFG/Parte2/little_images')
contador = 0
for file_path in images:
  os.rename(file_path, f'/content/drive/MyDrive/TFG/Parte2/little_images/pre-training_{contador}.jpg')
  contador += 1

# %% [markdown]
# ### Directorio principal
# Cambiar tamaño y nombre

# %%
images = subfiles('/content/drive/MyDrive/TFG/Parte2/images')
contador = 0

for file_path in images:
  file_name = os.path.basename(file_path)
  imagen = io.imread(file_path)
  nueva_imagen = cv2.resize(imagen, (1024, 512), interpolation = cv2.INTER_NEAREST)
  io.imsave(file_path, nueva_imagen, check_contrast=False)
  os.rename(file_path, f'/content/drive/MyDrive/TFG/Parte2/images/pre-training_{contador}.jpg')
  contador += 1

# %% [markdown]
# ### Directorio dataset target

# %%
train_x = subfiles('/content/drive/MyDrive/TFG/V2/nnUNet_raw/Dataset212_CholecSeg8kV2/imagesTr')

test_x = subfiles('/content/drive/MyDrive/TFG/V2/nnUNet_raw/Dataset212_CholecSeg8kV2/imagesTs')
test_y = subfiles('/content/drive/MyDrive/TFG/V2/evaluationV2/labelsTs')

num_files_to_move = int(len(train_x) * 0.2)

val_files = random.sample(train_x, num_files_to_move)

for file_path in train_x:
    parts = os.path.basename(file_path).split('_')
    new_filename = f"training-{parts[1]}.png"
    gt_prev_name = f'CS_{parts[1]}.png'
    new_gt_name = f"training_groundtruth-{parts[1]}.png"
    gt_path = f'/content/drive/MyDrive/TFG/V2/nnUNet_raw/Dataset212_CholecSeg8kV2/labelsTr/{gt_prev_name}'
    imagen = io.imread(file_path)
    nueva_imagen = cv2.resize(imagen, (1024, 512), interpolation = cv2.INTER_NEAREST)
    label = io.imread(gt_path)
    nueva_label = cv2.resize(label, (1024, 512), interpolation = cv2.INTER_NEAREST)
    if file_path in val_files:
      io.imsave(f'/content/drive/MyDrive/TFG/Parte2/target_data/val/x/{new_filename}', nueva_imagen, check_contrast=False)
      io.imsave(f'/content/drive/MyDrive/TFG/Parte2/target_data/val/y/{new_gt_name}', nueva_label, check_contrast=False)
    else:
      io.imsave(f'/content/drive/MyDrive/TFG/Parte2/target_data/train/x/{new_filename}', nueva_imagen, check_contrast=False)
      io.imsave(f'/content/drive/MyDrive/TFG/Parte2/target_data/train/y/{new_gt_name}', nueva_label, check_contrast=False)

for file_path in test_x:
    parts = os.path.basename(file_path).split('_')
    new_filename = f"testing-{parts[1]}.png"
    imagen = io.imread(file_path)
    nueva_imagen = cv2.resize(imagen, (1024, 512), interpolation = cv2.INTER_NEAREST)
    io.imsave(f'/content/drive/MyDrive/TFG/Parte2/target_data/test/x/{new_filename}', nueva_imagen, check_contrast=False)

for file_path in test_y:
    parts = os.path.basename(file_path).split('_')
    new_filename = f"testing_groundtruth-{parts[1]}"
    imagen = io.imread(file_path)
    nueva_imagen = cv2.resize(imagen, (1024, 512), interpolation = cv2.INTER_NEAREST)
    io.imsave(f'/content/drive/MyDrive/TFG/Parte2/target_data/test/y/{new_filename}', nueva_imagen, check_contrast=False)

# %% [markdown]
# ### Directorio feature maps

# %%
all_files = subfiles('/content/drive/MyDrive/TFG/Parte2/DSSL/simsiam_hyperKvir/logs/resnet50/feature_maps_light')
test_files = random.sample(all_files, int(len(all_files)*0.2))
training_files = list(set(all_files) - set(test_files))
val_files = random.sample(training_files, int(len(training_files)*0.2))
train_files = list(set(training_files) - set(val_files))

for file_path in train_files:
  shutil.move(file_path, '/content/drive/MyDrive/TFG/Parte2/DSSL/simsiam_hyperKvir/logs/resnet50/feature_maps_light/train')

for file_path in val_files:
  shutil.move(file_path, '/content/drive/MyDrive/TFG/Parte2/DSSL/simsiam_hyperKvir/logs/resnet50/feature_maps_light/val')

for file_path in test_files:
  shutil.move(file_path, '/content/drive/MyDrive/TFG/Parte2/DSSL/simsiam_hyperKvir/logs/resnet50/feature_maps_light/test')

# %%
prev_train = subfiles('/content/drive/MyDrive/TFG/Parte2/DSSL/simsiam_hyperKvir/logs/resnet50/feature_maps_light/train')
prev_val = subfiles('/content/drive/MyDrive/TFG/Parte2/DSSL/simsiam_hyperKvir/logs/resnet50/feature_maps_light/val')
prev_test = subfiles('/content/drive/MyDrive/TFG/Parte2/DSSL/simsiam_hyperKvir/logs/resnet50/feature_maps_light/test')

all_files = prev_train + prev_val + prev_test
test_files = random.sample(all_files, int(len(all_files)*0.1))
training_files = list(set(all_files) - set(test_files))
val_files = random.sample(training_files, int(len(training_files)*0.1))
train_files = list(set(training_files) - set(val_files))

for file_path in train_files:
  try:
    shutil.move(file_path, '/content/drive/MyDrive/TFG/Parte2/DSSL/simsiam_hyperKvir/logs/resnet50/feature_maps_light/train')
  except Exception as e:
    continue

for file_path in val_files:
  try:
    shutil.move(file_path, '/content/drive/MyDrive/TFG/Parte2/DSSL/simsiam_hyperKvir/logs/resnet50/feature_maps_light/val')
  except Exception as e:
    continue

for file_path in test_files:
  try:
    shutil.move(file_path, '/content/drive/MyDrive/TFG/Parte2/DSSL/simsiam_hyperKvir/logs/resnet50/feature_maps_light/test')
  except Exception as e:
    continue

# %% [markdown]
# ### Labels

# %%
train_y = subfiles('/content/drive/MyDrive/TFG/Parte2/target_data/train/y')
val_y = subfiles('/content/drive/MyDrive/TFG/Parte2/target_data/val/y')
test_y = subfiles('/content/drive/MyDrive/TFG/Parte2/target_data/test/y')

for file_path in train_y:
  img = io.imread(file_path)
  imagen = img[:,:,0]
  io.imsave(file_path, imagen, check_contrast=False)

for file_path in val_y:
  img = io.imread(file_path)
  imagen = img[:,:,0]
  io.imsave(file_path, imagen, check_contrast=False)

for file_path in test_y:
  img = io.imread(file_path)
  imagen = img[:,:,0]
  io.imsave(file_path, imagen, check_contrast=False)

# %% [markdown]
# ## Etapa 1: Contrastive Pre-training

# %%
cd /content/drive/MyDrive/TFG/Parte2/DSSL/simsiam_hyperKvir
# Out:
# /content/drive/MyDrive/TFG/Parte2/DSSL/simsiam_hyperKvir

# %%
ls

# %% [markdown]
# ### Cálculo de Media y Desviación Típica del dataset

# %%
from pathlib import Path
import cv2
import numpy as np

imageFilesDir = Path(r'/content/drive/MyDrive/TFG/Parte2/little_images')
files = list(imageFilesDir.rglob('*.jpg'))

# Since the std can't be calculated by simply finding it for each image and averaging like
# the mean can be, to get the std we first calculate the overall mean in a first run then
# run it again to get the std.

mean = np.array([0.,0.,0.])
stdTemp = np.array([0.,0.,0.])
std = np.array([0.,0.,0.])

numSamples = len(files)

for i in range(numSamples):
    im = cv2.imread(str(files[i]))
    im = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)
    im = im.astype(float) / 255.

    for j in range(3):
        mean[j] += np.mean(im[:,:,j])

mean = (mean/numSamples)

for i in range(numSamples):
    im = cv2.imread(str(files[i]))
    im = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)
    im = im.astype(float) / 255.
    for j in range(3):
        stdTemp[j] += ((im[:,:,j] - mean[j])**2).sum()/(im.shape[0]*im.shape[1])

std = np.sqrt(stdTemp/numSamples)

print(mean)
print(std)
# Out:
# [0.48620516 0.31784377 0.25886572]
# [0.33347277 0.24821133 0.22680829]

# %% [markdown]
# ### Primer entrenamiento

# %%
# !python3 main_simsiam.py --data /content/drive/MyDrive/TFG/Parte2/images --arch 'resnet50'\
    --work_dir '/content/drive/MyDrive/TFG/Parte2/DSSL/simsiam_hyperKvir/logs/resnet50' --workers 6 \
    --epochs 250 --batch-size 16 --lr 0.01 --print-freq 1000000 --gpu 0
# Out:
# /content/drive/MyDrive/TFG/Parte2/DSSL/simsiam_hyperKvir/main_simsiam.py:223: UserWarning: You have chosen a specific GPU. This will completely disable data parallelism.
#   warnings.warn('You have chosen a specific GPU. This will completely '
# Using GPU: 0 for training
# => Creating model 'resnet50'
# SimSiam(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# ...

# %% [markdown]
# ### Resto de entrenamientos

# %%
# !python3 main_simsiam.py --data /content/drive/MyDrive/TFG/Parte2/images --arch 'resnet50'\
    --work_dir '/content/drive/MyDrive/TFG/Parte2/DSSL/simsiam_hyperKvir/logs/resnet50' --workers 6 \
    --epochs 250 --batch-size 16 --lr 0.01 --print-freq 1000000 --gpu 0 --resume '/content/drive/MyDrive/TFG/Parte2/DSSL/simsiam_hyperKvir/logs/resnet50/checkpoint_latest.pth.tar'
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# 19013
# 19014
# 19015
# 19016
# 19017
# 19018
# 19019
# 19020
# 19021
# 19022
# 19023
# 19024
#  79% 1189/1501 [17:29<03:18,  1.57it/s]19025
# 19026
# 19027
# 19028
# 19029
# 19030
# 19031
# 19032
# 19033
# 19034
# 19035
# 19036
# 19037
# 19038
# 19039
# 19040
#  79% 1190/1501 [17:29<03:17,  1.57it/s]19041
# 19042
# 19043
# 19044
# 19045
# 19046
# 19047
# 19048
# 19049
# 19050
# 19051
# 19052
# 19053
# 19054
# 19055
# 19056
#  79% 1191/1501 [17:30<03:19,  1.55it/s]19057
# 19058
# 19059
# 19060
# 19061
# 19062
# 19063
# 19064
# 19065
# 19066
# 19067
# 19068
# 19069
# 19070
# 19071
# 19072
#  79% 1192/1501 [17:31<03:18,  1.56it/s]19073
# 19074
# 19075
# 19076
# 19077
# 19078
# 19079
# 19080
# 19081
# 19082
# 19083
# 19084
# 19085
# 19086
# 19087
# 19088
#  79% 1193/1501 [17:31<03:17,  1.56it/s]19089
# 19090
# 19091
# 19092
# 19093
# 19094
# 19095
# 19096
# 19097
# 19098
# 19099
# 19100
# 19101
# 19102
# 19103
# 19104
# ...

# %% [markdown]
# ### Obtener Feature Maps
# Se usarán en la siguiente etapa

# %%
# !python3 get_features.py --data /content/drive/MyDrive/TFG/Parte2/images --arch 'resnet50'\
    --work-dir '/content/drive/MyDrive/TFG/Parte2/DSSL/simsiam_hyperKvir/logs/resnet50' --workers 6 \
    --batch-size 16 --gpu 0 --checkpoint-dir '/content/drive/MyDrive/TFG/Parte2/DSSL/simsiam_hyperKvir/logs/resnet50/checkpoint_latest.pth.tar'
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# 19013
# 19014
# 19015
# 19016
# 19017
# 19018
# 19019
# 19020
# 19021
# 19022
# 19023
# 19024
#  79% 1189/1501 [24:12<03:10,  1.64it/s]19025
# 19026
# 19027
# 19028
# 19029
# 19030
# 19031
# 19032
# 19033
# 19034
# 19035
# 19036
# 19037
# 19038
# 19039
# 19040
#  79% 1190/1501 [24:12<03:07,  1.66it/s]19041
# 19042
# 19043
# 19044
# 19045
# 19046
# 19047
# 19048
# 19049
# 19050
# 19051
# 19052
# 19053
# 19054
# 19055
# 19056
#  79% 1191/1501 [24:13<03:05,  1.67it/s]19057
# 19058
# 19059
# 19060
# 19061
# 19062
# 19063
# 19064
# 19065
# 19066
# 19067
# 19068
# 19069
# 19070
# 19071
# 19072
#  79% 1192/1501 [24:14<03:38,  1.41it/s]19073
# 19074
# 19075
# 19076
# 19077
# 19078
# 19079
# 19080
# 19081
# 19082
# 19083
# 19084
# 19085
# 19086
# 19087
# 19088
#  79% 1193/1501 [24:14<03:27,  1.49it/s]19089
# 19090
# 19091
# 19092
# 19093
# 19094
# 19095
# 19096
# 19097
# 19098
# 19099
# 19100
# 19101
# 19102
# 19103
# 19104
# ...

# %% [markdown]
# ## Etapa 2: Generative Pre-training

# %%
cd /content/drive/MyDrive/TFG/Parte2/MAE
# Out:
# /content/drive/MyDrive/TFG/Parte2/MAE

# %%
ls
# Out:
# logs/  main_mae_NoSplits.py  main_mae.py  models/  __pycache__/

# %% [markdown]
# ### Primer entrenamiento

# %%
# !python3 main_mae.py --data /content/drive/MyDrive/TFG/Parte2/DSSL/simsiam_hyperKvir/logs/resnet50/feature_maps_light\
    --work_dir '/content/drive/MyDrive/TFG/Parte2/MAE/logs' --workers 6 \
    --epochs 800 --batch-size 64 --gpu 0 --lr 0.01
# Out:
# Using GPU: 0 for training
# => Creating model 'MAE'
# MAE(
#   (encoder): SimpleViT(
#     (to_patch_embedding): Sequential(
#       (0): Rearrange('b c h w -> b (h w) c')
#       (1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#     )
#     (transformer): Transformer(
#       (norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       (layers): ModuleList(
#         (0-5): 6 x ModuleList(
#           (0): Attention(
#             (norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (attend): Softmax(dim=-1)
#             (to_qkv): Linear(in_features=512, out_features=1536, bias=False)
#             (to_out): Linear(in_features=512, out_features=512, bias=False)
#           )
#           (1): FeedForward(
#             (net): Sequential(
#               (0): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#               (1): Linear(in_features=512, out_features=2048, bias=True)
#               (2): GELU(approximate='none')
# ...

# %% [markdown]
# ### Resto de entrenamientos

# %%
# !python3 main_mae.py --data /content/drive/MyDrive/TFG/Parte2/DSSL/simsiam_hyperKvir/logs/resnet50/feature_maps_light\
    --work_dir '/content/drive/MyDrive/TFG/Parte2/MAE/logs' --workers 6 \
    --epochs 800 --batch-size 64 --gpu 0 --resume '/content/drive/MyDrive/TFG/Parte2/MAE/logs/checkpoint_latest_new.pth.tar'
# Out:
# Using GPU: 0 for training
# => Creating model 'MAE'
# MAE(
#   (encoder): SimpleViT(
#     (to_patch_embedding): Sequential(
#       (0): Rearrange('b c h w -> b (h w) c')
#       (1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#     )
#     (transformer): Transformer(
#       (norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       (layers): ModuleList(
#         (0-5): 6 x ModuleList(
#           (0): Attention(
#             (norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (attend): Softmax(dim=-1)
#             (to_qkv): Linear(in_features=512, out_features=1536, bias=False)
#             (to_out): Linear(in_features=512, out_features=512, bias=False)
#           )
#           (1): FeedForward(
#             (net): Sequential(
#               (0): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#               (1): Linear(in_features=512, out_features=2048, bias=True)
#               (2): GELU(approximate='none')
# ...

# %% [markdown]
# ## Etapa 3: Fine Tuning

# %%
cd /content/drive/MyDrive/TFG/Parte2/FineTune
# Out:
# /content/drive/MyDrive/TFG/Parte2/FineTune

# %%
ls
# Out:
# dataset/  losses.py            models/     __pycache__/  test/   utils/
# logs/     main_cholecseg8k.py  options.py  setlogger.py  train/

# %% [markdown]
# ### Cálculo de Media y Desviación Típica del dataset

# %%
from pathlib import Path
import cv2
import numpy as np

imageFilesDir = Path(r'/content/drive/MyDrive/TFG/Parte2/target_data/train/x')
files = list(imageFilesDir.rglob('*.png'))

# Since the std can't be calculated by simply finding it for each image and averaging like
# the mean can be, to get the std we first calculate the overall mean in a first run then
# run it again to get the std.

mean = np.array([0.,0.,0.])
stdTemp = np.array([0.,0.,0.])
std = np.array([0.,0.,0.])

numSamples = len(files)

for i in range(numSamples):
    im = cv2.imread(str(files[i]))
    im = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)
    im = im.astype(float) / 255.

    for j in range(3):
        mean[j] += np.mean(im[:,:,j])

mean = (mean/numSamples)

for i in range(numSamples):
    im = cv2.imread(str(files[i]))
    im = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)
    im = im.astype(float) / 255.
    for j in range(3):
        stdTemp[j] += ((im[:,:,j] - mean[j])**2).sum()/(im.shape[0]*im.shape[1])

std = np.sqrt(stdTemp/numSamples)

print(mean)
print(std)
# Out:
# [0.33738113 0.21249664 0.18119559]
# [0.28384577 0.2238891  0.19353008]

# %% [markdown]
# ### Entrenamiento 1

# %%
# !python3 main_cholecseg8k.py --train-dir /content/drive/MyDrive/TFG/Parte2/target_data/train \
  --val-dir /content/drive/MyDrive/TFG/Parte2/target_data/val --save-dir /content/drive/MyDrive/TFG/Parte2/FineTune/logs \
  --workers 6 --epochs 250 --batch-size 12 --learning-rate 0.001 \
  --contrastive-weights /content/drive/MyDrive/TFG/Parte2/DSSL/simsiam_hyperKvir/logs/resnet50/checkpoint_latest.pth.tar \
  --generative-weights /content/drive/MyDrive/TFG/Parte2/MAE/logs/checkpoint_ViT_latest_new.pth.tar \
  --gpu 0 --num_classes 13
# Out:
# Namespace(train_dir='/content/drive/MyDrive/TFG/Parte2/target_data/train', val_dir='/content/drive/MyDrive/TFG/Parte2/target_data/val', arch='resnet50', dataset='CholecSeg8k', save_dir='/content/drive/MyDrive/TFG/Parte2/FineTune/logs', workers=6, epochs=250, start_epoch=0, batch_size=12, lr=0.001, schedule=[120, 160], momentum=0.9, weight_decay=0.0001, contrastive_weights='/content/drive/MyDrive/TFG/Parte2/DSSL/simsiam_hyperKvir/logs/resnet50/checkpoint_latest.pth.tar', generative_weights='/content/drive/MyDrive/TFG/Parte2/MAE/logs/checkpoint_ViT_latest_new.pth.tar', resume='', seed=None, gpu=0, num_classes=13)
# Now time is :  2024-05-10T16:20:03.211013
# 05/10 04:20:03 PM | Using GPU: 0 for training
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/logging/__init__.py", line 1100, in emit
#     msg = self.format(record)
#   File "/usr/lib/python3.10/logging/__init__.py", line 943, in format
#     return fmt.format(record)
# ...

# %% [markdown]
# ### Resto de entrenamientos

# %%
# !python3 main_cholecseg8k.py --train-dir /content/drive/MyDrive/TFG/Parte2/target_data/train \
  --val-dir /content/drive/MyDrive/TFG/Parte2/target_data/val --save-dir /content/drive/MyDrive/TFG/Parte2/FineTune/logs \
  --workers 6 --epochs 250 --batch-size 12 --learning-rate 0.001 \
  --resume /content/drive/MyDrive/TFG/Parte2/FineTune/logs/CholecSeg8k/models/model_latest.pth \
  --gpu 0 --num_classes 13
# Out:
# Namespace(train_dir='/content/drive/MyDrive/TFG/Parte2/target_data/train', val_dir='/content/drive/MyDrive/TFG/Parte2/target_data/val', arch='resnet50', dataset='CholecSeg8k', save_dir='/content/drive/MyDrive/TFG/Parte2/FineTune/logs', workers=6, epochs=250, start_epoch=0, batch_size=12, lr=0.001, schedule=[120, 160], momentum=0.9, weight_decay=0.0001, contrastive_weights='', generative_weights='', resume='/content/drive/MyDrive/TFG/Parte2/FineTune/logs/CholecSeg8k/models/model_latest.pth', seed=None, gpu=0, num_classes=13)
# Now time is :  2024-05-18T19:54:57.433049
# 05/18 07:54:57 PM | Using GPU: 0 for training
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/logging/__init__.py", line 1100, in emit
#     msg = self.format(record)
#   File "/usr/lib/python3.10/logging/__init__.py", line 943, in format
#     return fmt.format(record)
#   File "/usr/lib/python3.10/logging/__init__.py", line 678, in format
# ...

# %% [markdown]
# ### T = 10

# %%
# !python3 main_cholecseg8k.py --train-dir /content/drive/MyDrive/TFG/Parte2/Dataset_100/train \
  --val-dir /content/drive/MyDrive/TFG/Parte2/Dataset_100/val --save-dir /content/drive/MyDrive/TFG/Parte2/FineTune/logs_100 \
  --workers 6 --epochs 50 --batch-size 2 --learning-rate 0.001 \
  --contrastive-weights /content/drive/MyDrive/TFG/Parte2/DSSL/simsiam_hyperKvir/logs/resnet50/checkpoint_latest.pth.tar \
  --generative-weights /content/drive/MyDrive/TFG/Parte2/MAE/logs/checkpoint_ViT_latest_new.pth.tar \
  --gpu 0 --num_classes 13
# Out:
# Namespace(train_dir='/content/drive/MyDrive/TFG/Parte2/Dataset_100/train', val_dir='/content/drive/MyDrive/TFG/Parte2/Dataset_100/val', arch='resnet50', dataset='CholecSeg8k', save_dir='/content/drive/MyDrive/TFG/Parte2/FineTune/logs_100', workers=6, epochs=50, start_epoch=0, batch_size=2, lr=0.001, schedule=[120, 160], momentum=0.9, weight_decay=0.0001, contrastive_weights='/content/drive/MyDrive/TFG/Parte2/DSSL/simsiam_hyperKvir/logs/resnet50/checkpoint_latest.pth.tar', generative_weights='/content/drive/MyDrive/TFG/Parte2/MAE/logs/checkpoint_ViT_latest_new.pth.tar', resume='', seed=None, gpu=0, num_classes=13)
# Now time is :  2024-07-13T23:53:57.293175
# 07/13 11:53:57 PM | Using GPU: 0 for training
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/logging/__init__.py", line 1100, in emit
#     msg = self.format(record)
#   File "/usr/lib/python3.10/logging/__init__.py", line 943, in format
#     return fmt.format(record)
# ...

# %% [markdown]
# ## Postprocesado

# %%
import os
import shutil
import numpy as np
from batchgenerators.utilities.file_and_folder_operations import *
from skimage import io
import cv2
from google.colab.patches import cv2_imshow
import random

# %%
def colorear_seg_maps(seg_maps):
  seg2 = np.zeros((512, 1024, 3))

  seg2[:, :, 0] = seg_maps
  seg2[:, :, 1] = seg_maps
  seg2[:, :, 2] = seg_maps

  pixeles_0 = np.all(seg2 == [0, 0, 0], axis=2)
  pixeles_1 = np.all(seg2 == [1, 1, 1], axis=2)
  pixeles_2 = np.all(seg2 == [2, 2, 2], axis=2)
  pixeles_3 = np.all(seg2 == [3, 3, 3], axis=2)
  pixeles_4 = np.all(seg2 == [4, 4, 4], axis=2)
  pixeles_5 = np.all(seg2 == [5, 5, 5], axis=2)
  pixeles_6 = np.all(seg2 == [6, 6, 6], axis=2)
  pixeles_7 = np.all(seg2 == [7, 7, 7], axis=2)
  pixeles_8 = np.all(seg2 == [8, 8, 8], axis=2)
  pixeles_9 = np.all(seg2 == [9, 9, 9], axis=2)
  pixeles_10 = np.all(seg2 == [10, 10, 10], axis=2)
  pixeles_11 = np.all(seg2 == [11, 11, 11], axis=2)
  pixeles_12 = np.all(seg2 == [12, 12, 12], axis=2)


  seg2[pixeles_0] = [127, 127, 127]
  seg2[pixeles_1] = [210, 140, 140]
  seg2[pixeles_2] = [255, 114, 114]
  seg2[pixeles_3] = [231, 70, 156]
  seg2[pixeles_4] = [186, 183, 75]
  seg2[pixeles_5] = [170, 255, 0]
  seg2[pixeles_6] = [255, 85, 0]
  seg2[pixeles_7] = [255, 0, 0]
  seg2[pixeles_8] = [255, 255, 0]
  seg2[pixeles_9] = [169, 255, 184]
  seg2[pixeles_10] = [255, 160, 165]
  seg2[pixeles_11] = [0, 50, 128]
  seg2[pixeles_12] = [111, 74, 0]

  return seg2

# %%
test_predictions = subfiles('/content/drive/MyDrive/TFG/Parte2/FineTune/logs/CholecSeg8k/results/png')

for file_path in test_predictions:
    file_name = os.path.basename(file_path)
    imagen = io.imread(file_path)
    nueva_imagen = colorear_seg_maps(imagen)
    nueva_imagen = nueva_imagen.astype(np.uint8)
    nueva_imagen = cv2.resize(nueva_imagen, (854, 480), interpolation = cv2.INTER_NEAREST)
    nueva_imagen = nueva_imagen.astype(np.uint8)
    #io.imshow(nueva_imagen)
    io.imsave(file_path, nueva_imagen, check_contrast=False)

# %%
import matplotlib.pyplot as plt
import os

num = 7720

directorios = {'groundtruth': '/content/drive/MyDrive/TFG/Parte2/target_data/test/y',
               'prediction': '/content/drive/MyDrive/TFG/Parte2/FineTune/logs/CholecSeg8k/results/png',
               'input': '/content/drive/MyDrive/TFG/Parte2/target_data/test/x'}

nombres_imagenes = {'groundtruth': f'testing_groundtruth-{num}.png',
                    'prediction': f'test_prediction-{num}.png',
                    'input': f'testing-{num}.png'}


fig, axs = plt.subplots(1, 3, figsize=(15, 5))

for i, (tipo, directorio) in enumerate(directorios.items()):
    imagen_path = os.path.join(directorio, nombres_imagenes[tipo])
    imagen = io.imread(imagen_path)
    if tipo == 'groundtruth':
      print(imagen.shape)
      imagen = colorear_seg_maps(imagen)
      imagen = imagen.astype(np.uint8)
      imagen = cv2.resize(imagen, (854, 480), interpolation = cv2.INTER_NEAREST)
      imagen = imagen.astype(np.uint8)
    if tipo == 'input':
      imagen = cv2.resize(imagen, (854, 480), interpolation = cv2.INTER_NEAREST)
      imagen = imagen.astype(np.uint8)
    axs[i].imshow(imagen)
    axs[i].set_title(tipo.capitalize())
    axs[i].axis('off')

plt.tight_layout()
plt.show()
# Out:
# (512, 1024)

# %% [markdown]
# # Prueba
